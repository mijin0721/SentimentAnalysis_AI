# %% [markdown]
# <a href="https://colab.research.google.com/github/mijin0721/Sentiment_analysis_AI/blob/main/%EA%B2%B0%EA%B3%BC%EB%8F%84%EC%B6%9C_No3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.models import load_model

model = load_model('/content/drive/MyDrive/RNN_LSTM.h5')

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding_2 (Embedding)     (None, None, 100)         177200
#
#  lstm_2 (LSTM)               (None, 128)               117248
#
#  dense_2 (Dense)             (None, 5)                 645
#
#  dense_3 (Dense)             (None, 1)                 6
#
# ...
# Total params: 295,099
# Trainable params: 295,099
# Non-trainable params: 0
# _________________________________________________________________

# %%
import pandas as pd

data = pd.read_csv('/content/기말과제.csv',encoding='utf-8')
data
# Out:
#      Unnamed: 0                                            reviews
# 0             0  아 이거 왜 안됨 내가 하다하다 못해 카카오 스토리도 지우고 다 정리하고 그랬는데 ...
# 1             1  새방식이 좋다는 사람은 대부분 알바임 더 불편하고 비싸짐 이전처럼 이용권 사는방식이...
# 2             2  이거 진짜 혁명앱인데 내가 진짜 일반 모바일 결제앱 쓰다가 빡쳐서 후 우연히 토스 ...
# 3             3  저 이벤트 게임 그거 레벨 10레벨 다 됐눈데 캐시 왜 안오나요 \? 10레벨이 넘...
# 4             4                  엠티비도 이걸로 걷음 대학생 필수앱 더치페이 핵쉬움 , ,
# ..          ...                                                ...
# 995         995                   우리은행을 주거래로쓰고잇는데 우리은행은 추가안되나요 \?
# 996         996  제핸드폰기종이 폴더폰인데 폴더폰으로 등록이 안되나요 \? 꼭 이 스마트폰번호가 잇어...
# 997         997         갤럭시에도 얼굴인식으로 잠금이 해제 할 수 있게 추가 해주셨으면 좋겠습니다
# 998         998               5천원 종일권으로 좀 해주세요 아님 편당 페이지수를 늘려 주시던가
# 999         999                이거제가이모티콘받을수있게할려고2월전에 했는데안와요제작자님확이좀여
#
# [1000 rows x 2 columns]

# %%
data = data['reviews']

# %%
# !pip install konlpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import re
from konlpy.tag import Okt
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

okt = Okt()
tokenizer = Tokenizer()
max_len = 30
stopwords = ['의','가','이','은','들','는','좀','잘','걍','과','도','를','으로','자','에','와','한','하다']

def sentiment_predict_LSTM(new_sentence):
  new_sentence = re.sub(r'[^ㄱ-ㅎㅏ-ㅣ가-힣 ]','', new_sentence)
  new_sentence = okt.morphs(new_sentence, stem=True) # 토큰화
  new_sentence = [word for word in new_sentence if not word in stopwords] # 불용어 제거
  encoded = tokenizer.texts_to_sequences([new_sentence]) # 정수 인코딩
  pad_new = pad_sequences(encoded, maxlen = max_len) # 패딩
  score = float(model.predict(pad_new)) # 예측
  if(score > 0.5):
    return 1
  else:
    return 0

# %%
Answer = []
for i in range(len(data)):
    sentence = data[i]
    result = sentiment_predict_LSTM(sentence)
    Answer.append(result)
# Out:
# ...
# 1/1 [==============================] - 0s 28ms/step

# %%
Answer=pd.DataFrame(Answer,columns=['Answer'])
Answer
# Out:
#      Answer
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ..      ...
# 995       0
# 996       0
# 997       0
# 998       0
# 999       0
#
# [1000 rows x 1 columns]

# %%
Answer.to_csv('/content/result_BiLSTM.csv')
